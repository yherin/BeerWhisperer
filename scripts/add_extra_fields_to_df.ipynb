# %%
import pandas as pd
import pickle
import numpy as np
import fasttext
import fasttext.util
import json
from scipy import spatial
from nltk.corpus import stopwords
import nltk
stops = set(stopwords.words('english'))
stops.add('notes')
stops.add('note')
stops.add('hint')
stops.add('hints')

food_dict = json.load(open('../data/food_dict.json','r'))

# %%
df = pickle.load(open('../dataframe/model_df.bin','rb'))

# %%
alko_csv = pd.read_csv(open('../data/alkon-hinnasto-tekstitiedostona.csv', 'r'))

# %%
df = df.merge(alko_csv[['Numero','EAN']], left_on='Numero', right_on='Numero')

# %%
pickle.dump(df, open('../dataframe/model_df_v2.bin', 'wb'))

# %%
bin_df = pickle.load(open('../dataframe/model_df_v2.bin',  'rb'))

# %%
wmd = fasttext.load_model('../glove/wiki.en/wiki.en.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
def translate_foods(foods: list):
    return [food_dict[food][0] for food in foods]

# %%
bin_df['foods'] = bin_df.foods.apply(translate_foods)

# %%
bin_df[bin_df['Numero'] == 919855]['taste_desc'].values[0]
# Out:
# 'Straw-yellow, medium-bodied, cloudy, mildly hopped, aromatic, sour apple, citrus notes \n'

# %%
def compute_food_vectors(food_tags):
    tags_processed = []
    #print(food_tags)
    vect = np.zeros(300)
    #tags = food_tags.split(',')
    for tag in food_tags:
        tag = tag.strip().replace(r'-_',' ')
        tt = tag.split(' ')
        if type(tt) == list:
            tags_processed.extend(tt)
        else:
            tags_processed.append(tt)
    for t in tags_processed:
        #print(t)
        vect = np.add(vect, wmd.get_word_vector(t))
        #print(t, wmd.get_nearest_neighbors(t))
    return vect

# %%
bin_df['foods_vect'] = bin_df['foods'].apply(compute_food_vectors)

# %%
bin_df.columns
# Out:
# Index(['Numero', 'foods', 'taste_desc', 'taste_desc_partition', 'taste_vect',
#        'col_vect', 'feel_vect', 'Kantavierrep-%', 'Väri EBC', 'Katkerot EBU',
#        'Litrahinta', 'country_FI', 'country_EN', 'country_vect', 'EAN',
#        'foods_vect'],
#       dtype='object')

# %%
alkodf = pd.read_csv(open('../data/alkon-hinnasto-tekstitiedostona.csv','r'), sep = ',')
alkodf.columns
# Out:
# Index(['Numero', 'Nimi', 'Valmistaja', 'Pullokoko', 'Hinta', 'Litrahinta',
#        'Uutuus', 'Hinnastojärjestyskoodi', 'Tyyppi', 'Alatyyppi',
#        'Erityisryhmä', 'Oluttyyppi', 'Valmistusmaa', 'Alue', 'Vuosikerta',
#        'Etikettimerkintöjä', 'Huomautus', 'Rypäleet', 'Luonnehdinta',
#        'Pakkaustyyppi', 'Suljentatyyppi', 'Alkoholi-%', 'Hapot g/l',
#        'Sokeri g/l', 'Kantavierrep-%', 'Väri EBC', 'Katkerot EBU',
#        'Energia kcal/100 ml', 'Valikoima', 'EAN'],
#       dtype='object')

# %%
bin_df = bin_df.merge(alkodf[['Numero','Nimi']], left_on='Numero', right_on='Numero')

# %%
bin_df
# Out:
#       Numero                                              foods  \
# 0     718897  [tapas and antipasti, party wine, mild cheese,...
# 1     715894  [grilled food, chicken, turkey, mild cheese, p...
# 2     758594  [fatty fish, mild cheese, meditation beverage,...
# 3     730097  [strong cheeses, game birds, meditation bevera...
# 4     919855          [seafood, lean fish, meditation beverage]
# ...      ...                                                ...
# 1151  911916                  [party wine, meditation beverage]
# 1152  935551     [game, meditation beverage, chocolate deserts]
# 1153  906362  [berries and fruits, mild cheese, meditation b...
# 1154  951272  [berries and fruits, party wine, mild cheese, ...
# 1155  915304                        [liver, grilled food, lamb]
#
#                                              taste_desc  \
# 0     Golden-yellow, acidic, ripe apricot notes, tea...
# 1     Amber-yellow, full-bodied, cloudy, with a rich...
# 2     Caramel-brown, full-bodied, cloudy, with a ric...
# 3     Mahogany-brown, full-bodied, cloudy, with a ri...
# 4     Straw-yellow, medium-bodied, cloudy, mildly ho...
# ...                                                 ...
# 1151  Mahogany-brown, full-bodied, strongly hopped, ...
# 1152  Black, extra full-bodied, medium hopped, espre...
# 1153  Yellowy brown, light-bodied, mildly hopped, ci...
# 1154  Yellowy brown, light-bodied, mildly hopped, fr...
# 1155  Cinnamon-brown, extra full-bodied, cloudy, mil...
#
#                                    taste_desc_partition  \
# 0     ([golden yellow], [acidic], [ripe apricot, tea...
# 1     ([amber yellow], [full bodied], [cloudy, rich ...
# 2     ([caramel brown], [full bodied], [cloudy, rich...
# 3     ([mahogany brown], [full bodied], [cloudy, ric...
# 4     ([straw yellow], [medium bodied], [cloudy, mil...
# ...                                                 ...
# 1151  ([mahogany brown], [full bodied], [strongly ho...
# 1152  ([black], [extra full bodied], [medium hopped,...
# 1153  ([yellowy brown], [light bodied], [mildly hopp...
# 1154  ([yellowy brown], [light bodied], [mildly hopp...
# 1155  ([cinnamon brown], [extra full bodied], [cloud...
#
#                                              taste_vect  \
# 0     [0.07987281028181314, 0.43386150151491165, -0....
# 1     [-1.7081294995732605, 0.27396272122859955, -1....
# 2     [-1.6897689891047776, 0.5013146325945854, -2.0...
# 3     [-1.7472486239857972, 0.26350243110209703, -1....
# 4     [-0.9882284207269549, 0.47043924778699875, -1....
# ...                                                 ...
# 1151  [-1.485752671957016, -0.10107788443565369, -1....
# 1152  [-1.7364337434992194, 0.47930875420570374, -1....
# 1153  [-0.2375907376408577, -0.07339736819267273, -1...
# 1154  [-0.2375907376408577, -0.07339736819267273, -1...
# 1155  [-1.849965344183147, 0.2798819914460182, -2.21...
#
#                                                col_vect  \
# 0     [-0.9887842833995819, -0.05810368980746716, 0....
# 1     [-0.14614155888557434, 0.19808457244653255, 0....
# 2     [-0.3954937756061554, -0.3169432431459427, -0....
# 3     [-0.27681805193424225, -0.19199614971876144, 0...
# 4     [-0.757635623216629, -0.03374277602415532, -0....
# ...                                                 ...
# 1151  [-0.27681805193424225, -0.19199614971876144, 0...
# 1152  [-0.3380114436149597, -0.0010778139112517238, ...
# 1153  [-0.6801424920558929, -0.04885224997997284, -0...
# 1154  [-0.6801424920558929, -0.04885224997997284, -0...
# 1155  [0.09692773222923279, -0.24959075450897217, -0...
#
#                                               feel_vect  Kantavierrep-%  \
# 0     [-0.2133956402540207, 0.22910979390144348, -0....            26.6
# 1     [-0.1657096636481583, 0.44968753308057785, -0....            17.8
# 2     [-0.1657096636481583, 0.44968753308057785, -0....            18.5
# 3     [-0.1657096636481583, 0.44968753308057785, -0....            19.4
# 4     [-0.09927538456395268, 0.6873573958873749, 0.1...            17.6
# ...                                                 ...             ...
# 1151  [-0.1657096636481583, 0.44968753308057785, -0....            26.5
# 1152  [-0.2778867376036942, 0.6079885140061378, -0.5...            26.0
# 1153  [-0.2531137359328568, 0.38831834215670824, 0.2...            13.1
# 1154  [-0.2531137359328568, 0.38831834215670824, 0.2...            12.9
# 1155  [-0.2778867376036942, 0.6079885140061378, -0.5...            19.0
#
#       Väri EBC  Katkerot EBU  Litrahinta   country_FI     country_EN  \
# 0          NaN           NaN       23.92    Australia      australia
# 1         15.9          23.0       15.18       Belgia        belgium
# 2         41.8          24.0       16.18       Belgia        belgium
# 3         70.5          18.0       20.68       Belgia        belgium
# 4          NaN           7.0       16.42       Belgia        belgium
# ...        ...           ...         ...          ...            ...
# 1151      84.5          55.0       45.26  Yhdysvallat  united states
# 1152       NaN          49.0       40.86  Yhdysvallat  united states
# 1153       NaN          22.0       15.27       Belgia        belgium
# 1154       NaN          17.0       15.27       Belgia        belgium
# 1155       NaN           NaN       20.53        Suomi        finland
#
#                                            country_vect            EAN  \
# 0     [-0.2850604, -0.03134475, -0.22727826, 0.54968...  9317705000107
# 1     [-0.19977358, -0.12839371, -0.2806692, 0.11698...  5425007658828
# 2     [-0.19977358, -0.12839371, -0.2806692, 0.11698...  5425007658880
# 3     [-0.19977358, -0.12839371, -0.2806692, 0.11698...  5425007658859
# 4     [-0.19977358, -0.12839371, -0.2806692, 0.11698...  5425031890355
# ...                                                 ...            ...
# 1151  [0.045622084, -0.35862827, 0.1916659, 0.238043...   636251830341
# 1152  [0.045622084, -0.35862827, 0.1916659, 0.238043...   856467003074
# 1153  [-0.19977358, -0.12839371, -0.2806692, 0.11698...  5425018070893
# 1154  [-0.19977358, -0.12839371, -0.2806692, 0.11698...  5425018070626
# 1155  [-0.28281564, -0.27681777, -0.3363437, 0.19809...  6429810262004
#
#                                              foods_vect  \
# 0     [0.664138131774962, 0.3014734573662281, -1.479...
# 1     [-0.9217289164662361, 0.48395066149532795, -0....
# 2     [0.5714964913204312, 0.6492249220609665, -1.59...
# 3     [-0.7808311134576797, 0.035434480756521225, -1...
# 4     [-0.41338769625872374, 0.730044960975647, -0.9...
# ...                                                 ...
# 1151  [0.11925933137536049, -0.3152843862771988, -0....
# 1152  [-0.5057903826236725, -0.6452207937836647, -1....
# 1153  [-0.31398187205195427, -0.21874704211950302, -...
# 1154  [-0.10079468041658401, -0.7185215502977371, -0...
# 1155  [-0.1805492267012596, 0.31509122624993324, -0....
#
#                                                    Nimi
# 0                                    Maxwell Honey Mead
# 1                                           Achel Blond
# 2                                           Achel Bruin
# 3                                     Achel Extra Bruin
# 4                            Alvinne Phi Blond Sour Ale
# ...                                                 ...
# 1151                        Stone Southern Charred 2015
# 1152              Westbrook Mexican Cake Imperial Stout
# 1153  Oud Beersel Jasmine Flower Infused Lambic hana...
# 1154               Oud Beersel Rozenlambiek hanapakkaus
# 1155                Kullervo Tumma Ruissahti viinipussi
#
# [1156 rows x 17 columns]

# %%
pickle.dump(bin_df,open('../dataframe/model_df_v2.bin','wb'))
